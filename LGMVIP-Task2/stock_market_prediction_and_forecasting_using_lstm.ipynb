# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('stocks.csv')
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
df.isna().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df_high= df.reset_index()["High"]
print(df_high.head())
# Out:
# 0    235.95
# 1    236.80
# 2    240.00
# 3    236.75
# 4    239.20
# Name: High, dtype: float64

# %%
plt.plot(df_high)
plt.show()

# %% [markdown]
# # PreProcessing

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
df_high = MMS.fit_transform(df_high.values.reshape(-1,1))
df_high
# Out:
# array([[0.62268754],
#        [0.62614353],
#        [0.6391543 ],
#        ...,
#        [0.15917869],
#        [0.15938199],
#        [0.16344786]])

# %% [markdown]
# # Train,Test Split

# %%
train_size=int(len(df_high)*0.8)
test_size=len(df_high)-train_size

# %%
train_data=df_high[:train_size,:]
test_data=df_high[train_size:,:1]

# %%
train_data.shape
# Out:
# (1628, 1)

# %%
def create_data(data, time_step):
    X_data, y_data = [], []

    for i in range(len(data) - time_step - 1):
        prev = data[i: i+time_step, 0]
        X_data.append(prev)
        y_data.append(data[i+time_step, 0])

    return np.array(X_data), np.array(y_data)

# %%
time_step = 100

X_train, y_train = create_data(train_data, time_step)
X_test, y_test = create_data(test_data, time_step)

# %%
# Make 3-D data(LSTM Requirement) (samples, time steps, features)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_train.shape, y_train.shape
# Out:
# ((1527, 100, 1), (1527,))

# %%
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, LSTM

model = Sequential()

model.add(LSTM(50, return_sequences = True, input_shape = (100, 1)))
model.add(LSTM(50, return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))

model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 100, batch_size = 64, verbose = True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 20s 349ms/step - loss: 0.0319 - val_loss: 0.0060
# Epoch 2/100
# 24/24 [==============================] - 7s 287ms/step - loss: 0.0028 - val_loss: 7.1700e-04
# Epoch 3/100
# 24/24 [==============================] - 7s 290ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 4/100
# 24/24 [==============================] - 7s 293ms/step - loss: 0.0015 - val_loss: 9.6217e-04
# Epoch 5/100
# 24/24 [==============================] - 7s 307ms/step - loss: 0.0014 - val_loss: 8.6544e-04
# Epoch 6/100
# 24/24 [==============================] - 7s 304ms/step - loss: 0.0013 - val_loss: 8.8284e-04
# Epoch 7/100
# 24/24 [==============================] - 7s 294ms/step - loss: 0.0013 - val_loss: 8.8863e-04
# Epoch 8/100
# 24/24 [==============================] - 7s 307ms/step - loss: 0.0012 - val_loss: 6.7370e-04
# Epoch 9/100
# 24/24 [==============================] - 7s 293ms/step - loss: 0.0012 - val_loss: 6.7120e-04
# Epoch 10/100
# 24/24 [==============================] - 7s 288ms/step - loss: 0.0011 - val_loss: 4.9147e-04
# Epoch 11/100
# 24/24 [==============================] - 7s 288ms/step - loss: 0.0011 - val_loss: 6.7690e-04
# Epoch 12/100
# 24/24 [==============================] - 7s 286ms/step - loss: 0.0011 - val_loss: 6.2891e-04
# Epoch 13/100
# 24/24 [==============================] - 7s 284ms/step - loss: 9.5455e-04 - val_loss: 5.7511e-04
# Epoch 14/100
# 24/24 [==============================] - 7s 292ms/step - loss: 8.4253e-04 - val_loss: 5.1469e-04
# Epoch 15/100
# 24/24 [==============================] - 7s 285ms/step - loss: 8.1402e-04 - val_loss: 5.2267e-04
# Epoch 16/100
# 24/24 [==============================] - 7s 283ms/step - loss: 8.6084e-04 - val_loss: 5.1331e-04
# Epoch 17/100
# 24/24 [==============================] - 7s 286ms/step - loss: 7.7321e-04 - val_loss: 5.5259e-04
# Epoch 18/100
# 24/24 [==============================] - 7s 285ms/step - loss: 7.5388e-04 - val_loss: 5.3996e-04
# Epoch 19/100
# 24/24 [==============================] - 7s 285ms/step - loss: 7.2182e-04 - val_loss: 6.1357e-04
# Epoch 20/100
# 24/24 [==============================] - 7s 287ms/step - loss: 6.9754e-04 - val_loss: 7.5920e-04
# Epoch 21/100
# 24/24 [==============================] - 7s 286ms/step - loss: 6.6476e-04 - val_loss: 5.7352e-04
# Epoch 22/100
# 24/24 [==============================] - 7s 285ms/step - loss: 6.2866e-04 - val_loss: 5.1098e-04
# Epoch 23/100
# 24/24 [==============================] - 7s 288ms/step - loss: 6.2264e-04 - val_loss: 4.4436e-04
# Epoch 24/100
# 24/24 [==============================] - 7s 286ms/step - loss: 6.4739e-04 - val_loss: 4.3602e-04
# Epoch 25/100
# 24/24 [==============================] - 7s 286ms/step - loss: 7.1457e-04 - val_loss: 4.0824e-04
# Epoch 26/100
# 24/24 [==============================] - 7s 285ms/step - loss: 6.1331e-04 - val_loss: 5.0191e-04
# Epoch 27/100
# 24/24 [==============================] - 7s 284ms/step - loss: 6.3525e-04 - val_loss: 4.3741e-04
# Epoch 28/100
# 24/24 [==============================] - 7s 283ms/step - loss: 6.9073e-04 - val_loss: 3.7084e-04
# Epoch 29/100
# 24/24 [==============================] - 7s 281ms/step - loss: 5.5799e-04 - val_loss: 4.4439e-04
# Epoch 30/100
# 24/24 [==============================] - 7s 285ms/step - loss: 5.2293e-04 - val_loss: 4.3313e-04
# Epoch 31/100
# 24/24 [==============================] - 7s 284ms/step - loss: 5.0920e-04 - val_loss: 3.8001e-04
# Epoch 32/100
# 24/24 [==============================] - 7s 286ms/step - loss: 5.2194e-04 - val_loss: 3.8680e-04
# Epoch 33/100
# 24/24 [==============================] - 7s 294ms/step - loss: 5.2229e-04 - val_loss: 3.8502e-04
# Epoch 34/100
# 24/24 [==============================] - 7s 287ms/step - loss: 4.9986e-04 - val_loss: 3.2402e-04
# Epoch 35/100
# 24/24 [==============================] - 7s 291ms/step - loss: 5.0046e-04 - val_loss: 3.6275e-04
# Epoch 36/100
# 24/24 [==============================] - 7s 297ms/step - loss: 4.4392e-04 - val_loss: 3.4336e-04
# Epoch 37/100
# 24/24 [==============================] - 7s 272ms/step - loss: 4.3132e-04 - val_loss: 3.1400e-04
# Epoch 38/100
# 24/24 [==============================] - 6s 266ms/step - loss: 4.6308e-04 - val_loss: 3.1534e-04
# Epoch 39/100
# 24/24 [==============================] - 7s 274ms/step - loss: 4.1368e-04 - val_loss: 3.4671e-04
# Epoch 40/100
# 24/24 [==============================] - 6s 268ms/step - loss: 4.7591e-04 - val_loss: 4.4649e-04
# Epoch 41/100
# 24/24 [==============================] - 7s 277ms/step - loss: 4.1401e-04 - val_loss: 3.5349e-04
# Epoch 42/100
# 24/24 [==============================] - 7s 279ms/step - loss: 3.9612e-04 - val_loss: 2.7687e-04
# Epoch 43/100
# 24/24 [==============================] - 7s 292ms/step - loss: 3.9283e-04 - val_loss: 3.2702e-04
# Epoch 44/100
# 24/24 [==============================] - 7s 289ms/step - loss: 3.7787e-04 - val_loss: 2.7887e-04
# Epoch 45/100
# 24/24 [==============================] - 7s 295ms/step - loss: 3.7782e-04 - val_loss: 2.8179e-04
# Epoch 46/100
# 24/24 [==============================] - 7s 299ms/step - loss: 3.7808e-04 - val_loss: 2.4801e-04
# Epoch 47/100
# 24/24 [==============================] - 7s 294ms/step - loss: 3.4874e-04 - val_loss: 2.7772e-04
# Epoch 48/100
# 24/24 [==============================] - 7s 297ms/step - loss: 3.4979e-04 - val_loss: 2.4127e-04
# Epoch 49/100
# 24/24 [==============================] - 7s 288ms/step - loss: 3.5163e-04 - val_loss: 2.3693e-04
# Epoch 50/100
# 24/24 [==============================] - 7s 290ms/step - loss: 4.1348e-04 - val_loss: 3.6401e-04
# Epoch 51/100
# 24/24 [==============================] - 7s 292ms/step - loss: 3.7895e-04 - val_loss: 2.4346e-04
# Epoch 52/100
# 24/24 [==============================] - 7s 296ms/step - loss: 3.0099e-04 - val_loss: 2.3521e-04
# Epoch 53/100
# 24/24 [==============================] - 7s 294ms/step - loss: 3.3956e-04 - val_loss: 2.4470e-04
# Epoch 54/100
# 24/24 [==============================] - 7s 298ms/step - loss: 2.9590e-04 - val_loss: 2.6835e-04
# Epoch 55/100
# 24/24 [==============================] - 7s 280ms/step - loss: 2.8421e-04 - val_loss: 2.4042e-04
# Epoch 56/100
# 24/24 [==============================] - 7s 292ms/step - loss: 3.0950e-04 - val_loss: 2.3732e-04
# Epoch 57/100
# 24/24 [==============================] - 7s 286ms/step - loss: 3.0063e-04 - val_loss: 2.0845e-04
# Epoch 58/100
# 24/24 [==============================] - 7s 280ms/step - loss: 2.6983e-04 - val_loss: 2.8403e-04
# Epoch 59/100
# 24/24 [==============================] - 7s 288ms/step - loss: 2.7827e-04 - val_loss: 2.8162e-04
# Epoch 60/100
# 24/24 [==============================] - 7s 293ms/step - loss: 2.9928e-04 - val_loss: 2.2664e-04
# Epoch 61/100
# 24/24 [==============================] - 7s 305ms/step - loss: 2.6331e-04 - val_loss: 2.3261e-04
# Epoch 62/100
# 24/24 [==============================] - 7s 286ms/step - loss: 2.7043e-04 - val_loss: 2.1737e-04
# Epoch 63/100
# 24/24 [==============================] - 7s 288ms/step - loss: 2.4314e-04 - val_loss: 2.0085e-04
# Epoch 64/100
# 24/24 [==============================] - 7s 283ms/step - loss: 2.5395e-04 - val_loss: 1.8283e-04
# Epoch 65/100
# 24/24 [==============================] - 7s 289ms/step - loss: 2.5317e-04 - val_loss: 1.9362e-04
# Epoch 66/100
# 24/24 [==============================] - 7s 286ms/step - loss: 2.7137e-04 - val_loss: 2.4187e-04
# Epoch 67/100
# 24/24 [==============================] - 7s 292ms/step - loss: 2.4924e-04 - val_loss: 2.9032e-04
# Epoch 68/100
# 24/24 [==============================] - 7s 290ms/step - loss: 2.6055e-04 - val_loss: 1.8135e-04
# Epoch 69/100
# 24/24 [==============================] - 7s 292ms/step - loss: 2.3325e-04 - val_loss: 1.8030e-04
# Epoch 70/100
# 24/24 [==============================] - 7s 282ms/step - loss: 2.3034e-04 - val_loss: 1.9119e-04
# Epoch 71/100
# 24/24 [==============================] - 7s 297ms/step - loss: 2.3330e-04 - val_loss: 2.2849e-04
# Epoch 72/100
# 24/24 [==============================] - 7s 281ms/step - loss: 2.3434e-04 - val_loss: 1.6662e-04
# Epoch 73/100
# 24/24 [==============================] - 6s 257ms/step - loss: 2.8857e-04 - val_loss: 2.3400e-04
# Epoch 74/100
# 24/24 [==============================] - 6s 257ms/step - loss: 2.8469e-04 - val_loss: 1.8253e-04
# Epoch 75/100
# 24/24 [==============================] - 6s 265ms/step - loss: 2.3037e-04 - val_loss: 1.6591e-04
# Epoch 76/100
# 24/24 [==============================] - 7s 290ms/step - loss: 2.0382e-04 - val_loss: 1.6438e-04
# Epoch 77/100
# 24/24 [==============================] - 7s 281ms/step - loss: 2.4235e-04 - val_loss: 1.6343e-04
# Epoch 78/100
# 24/24 [==============================] - 7s 280ms/step - loss: 2.1278e-04 - val_loss: 1.5967e-04
# Epoch 79/100
# 24/24 [==============================] - 7s 289ms/step - loss: 2.2639e-04 - val_loss: 1.7929e-04
# Epoch 80/100
# 24/24 [==============================] - 7s 287ms/step - loss: 2.3570e-04 - val_loss: 1.6134e-04
# Epoch 81/100
# 24/24 [==============================] - 7s 298ms/step - loss: 2.2388e-04 - val_loss: 1.6189e-04
# Epoch 82/100
# 24/24 [==============================] - 7s 297ms/step - loss: 1.9254e-04 - val_loss: 1.8585e-04
# Epoch 83/100
# 24/24 [==============================] - 7s 285ms/step - loss: 1.8849e-04 - val_loss: 1.8841e-04
# Epoch 84/100
# 24/24 [==============================] - 7s 283ms/step - loss: 1.8850e-04 - val_loss: 1.7095e-04
# Epoch 85/100
# 24/24 [==============================] - 7s 293ms/step - loss: 1.8668e-04 - val_loss: 1.4613e-04
# Epoch 86/100
# 24/24 [==============================] - 7s 292ms/step - loss: 1.8862e-04 - val_loss: 1.6903e-04
# Epoch 87/100
# 24/24 [==============================] - 7s 293ms/step - loss: 2.0342e-04 - val_loss: 2.5066e-04
# Epoch 88/100
# 24/24 [==============================] - 7s 289ms/step - loss: 1.9792e-04 - val_loss: 1.5868e-04
# Epoch 89/100
# 24/24 [==============================] - 7s 284ms/step - loss: 1.9007e-04 - val_loss: 1.4409e-04
# Epoch 90/100
# 24/24 [==============================] - 7s 293ms/step - loss: 1.8214e-04 - val_loss: 1.4572e-04
# Epoch 91/100
# 24/24 [==============================] - 7s 286ms/step - loss: 2.0830e-04 - val_loss: 1.6427e-04
# Epoch 92/100
# 24/24 [==============================] - 7s 291ms/step - loss: 1.8567e-04 - val_loss: 1.5233e-04
# Epoch 93/100
# 24/24 [==============================] - 7s 289ms/step - loss: 1.8020e-04 - val_loss: 1.7471e-04
# Epoch 94/100
# 24/24 [==============================] - 7s 287ms/step - loss: 1.7742e-04 - val_loss: 1.4686e-04
# Epoch 95/100
# 24/24 [==============================] - 7s 296ms/step - loss: 1.8231e-04 - val_loss: 1.6810e-04
# Epoch 96/100
# 24/24 [==============================] - 7s 300ms/step - loss: 1.7766e-04 - val_loss: 1.4385e-04
# Epoch 97/100
# 24/24 [==============================] - 7s 290ms/step - loss: 2.0029e-04 - val_loss: 1.3371e-04
# Epoch 98/100
# 24/24 [==============================] - 7s 292ms/step - loss: 1.7495e-04 - val_loss: 1.8447e-04
# Epoch 99/100
# 24/24 [==============================] - 7s 292ms/step - loss: 1.8059e-04 - val_loss: 1.3046e-04
# Epoch 100/100
# 24/24 [==============================] - 7s 297ms/step - loss: 2.6594e-04 - val_loss: 1.4134e-04

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
from math import sqrt
from sklearn.metrics import  mean_squared_error

rmse_train = sqrt(mean_squared_error(y_train, train_predict))
rmse_test = sqrt(mean_squared_error(y_test, test_predict))
rmse_train, rmse_test
# Out:
# (0.016861615281126407, 0.01188875083748524)

# %%
look_back = 100

trainPredictPlot = np.empty_like(df_high)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back: len(train_predict) + look_back, :] = train_predict

testPredictPlot = np.empty_like(df_high)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1: len(df_high) - 1, :] = test_predict

# %%
plt.plot(MMS.inverse_transform(df_high))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)

plt.legend(labels = ['Complete data', 'Train data', 'Predicted data'])
plt.show()
